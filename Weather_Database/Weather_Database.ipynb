# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Import the requests library.
import requests

# Import the OpenWeather API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for OpenWeather Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# For each city, call API, retrieve data, and add to dataframe

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes. Wait 60 secs between each set to stay within API call limit
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create complete URL by adding city name.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # get weather description
        city_weather_desc = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          # Add weather description to dataframe
                          "Description": city_weather_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jurm
# Processing Record 2 of Set 1 | narasannapeta
# Processing Record 3 of Set 1 | klaksvik
# Processing Record 4 of Set 1 | constitucion
# Processing Record 5 of Set 1 | tuatapere
# Processing Record 6 of Set 1 | bom jesus
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | pangnirtung
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | siderno
# Processing Record 11 of Set 1 | gao
# Processing Record 12 of Set 1 | camacha
# Processing Record 13 of Set 1 | ha tinh
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | dhone
# Processing Record 20 of Set 1 | killybegs
# Processing Record 21 of Set 1 | port elizabeth
# Processing Record 22 of Set 1 | tecoanapa
# Processing Record 23 of Set 1 | castro
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | tiksi
# Processing Record 28 of Set 1 | mahebourg
# Processing Record 29 of Set 1 | road town
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | bilibino
# Processing Record 34 of Set 1 | pinawa
# Processing Record 35 of Set 1 | airai
# Processing Record 36 of Set 1 | bambous virieux
# Processing Record 37 of Set 1 | mehamn
# Processing Record 38 of Set 1 | opuwo
# Processing Record 39 of Set 1 | adrar
# Processing Record 40 of Set 1 | eskasem
# City not found. Skipping...
# Processing Record 41 of Set 1 | kieta
# Processing Record 42 of Set 1 | bowen
# Processing Record 43 of Set 1 | isangel
# Processing Record 44 of Set 1 | itoman
# Processing Record 45 of Set 1 | lorengau
# Processing Record 46 of Set 1 | alofi
# Processing Record 47 of Set 1 | tasiilaq
# Processing Record 48 of Set 1 | abu kamal
# Processing Record 49 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 1 | ribeira grande
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | teguldet
# Processing Record 3 of Set 2 | provideniya
# Processing Record 4 of Set 2 | nikolskoye
# Processing Record 5 of Set 2 | sungai siput utara
# City not found. Skipping...
# Processing Record 6 of Set 2 | arraial do cabo
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | sovetskiy
# Processing Record 10 of Set 2 | matsubase
# Processing Record 11 of Set 2 | poplar bluff
# Processing Record 12 of Set 2 | burnie
# Processing Record 13 of Set 2 | tilichiki
# Processing Record 14 of Set 2 | ola
# Processing Record 15 of Set 2 | butaritari
# Processing Record 16 of Set 2 | marzuq
# Processing Record 17 of Set 2 | lebu
# Processing Record 18 of Set 2 | aklavik
# Processing Record 19 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 2 | saint-joseph
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | humaita
# Processing Record 23 of Set 2 | san juan de uraba
# Processing Record 24 of Set 2 | bathsheba
# Processing Record 25 of Set 2 | east london
# Processing Record 26 of Set 2 | new norfolk
# Processing Record 27 of Set 2 | itarema
# Processing Record 28 of Set 2 | leshukonskoye
# Processing Record 29 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 2 | bitung
# Processing Record 31 of Set 2 | khatanga
# Processing Record 32 of Set 2 | chokurdakh
# Processing Record 33 of Set 2 | caravelas
# Processing Record 34 of Set 2 | nizwa
# Processing Record 35 of Set 2 | cidreira
# Processing Record 36 of Set 2 | nouadhibou
# Processing Record 37 of Set 2 | hilo
# Processing Record 38 of Set 2 | ilulissat
# Processing Record 39 of Set 2 | carnarvon
# Processing Record 40 of Set 2 | nioro
# Processing Record 41 of Set 2 | cockburn town
# Processing Record 42 of Set 2 | ostrovnoy
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | tabou
# Processing Record 45 of Set 2 | port hardy
# Processing Record 46 of Set 2 | liverpool
# Processing Record 47 of Set 2 | geraldton
# Processing Record 48 of Set 2 | armacao dos buzios
# City not found. Skipping...
# Processing Record 49 of Set 2 | guerrero negro
# Processing Record 50 of Set 2 | thompson
# Processing Record 1 of Set 3 | klyuchi
# Processing Record 2 of Set 3 | havre-saint-pierre
# Processing Record 3 of Set 3 | sorong
# Processing Record 4 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 3 | zeya
# Processing Record 6 of Set 3 | narsaq
# Processing Record 7 of Set 3 | esperance
# Processing Record 8 of Set 3 | bredasdorp
# Processing Record 9 of Set 3 | hambantota
# Processing Record 10 of Set 3 | nha trang
# Processing Record 11 of Set 3 | moose factory
# Processing Record 12 of Set 3 | noyabrsk
# Processing Record 13 of Set 3 | terrace
# Processing Record 14 of Set 3 | golden
# Processing Record 15 of Set 3 | alberton
# Processing Record 16 of Set 3 | vaini
# Processing Record 17 of Set 3 | sao jose de piranhas
# Processing Record 18 of Set 3 | atuona
# Processing Record 19 of Set 3 | livingston
# Processing Record 20 of Set 3 | port blair
# Processing Record 21 of Set 3 | neyshabur
# Processing Record 22 of Set 3 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 23 of Set 3 | norman wells
# Processing Record 24 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 3 | atasu
# Processing Record 26 of Set 3 | buariki
# City not found. Skipping...
# Processing Record 27 of Set 3 | blackwater
# Processing Record 28 of Set 3 | veraval
# Processing Record 29 of Set 3 | kavaratti
# Processing Record 30 of Set 3 | longyearbyen
# Processing Record 31 of Set 3 | san jose
# Processing Record 32 of Set 3 | hailar
# Processing Record 33 of Set 3 | antalaha
# Processing Record 34 of Set 3 | kansanshi
# Processing Record 35 of Set 3 | tadine
# Processing Record 36 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 37 of Set 3 | nizhneangarsk
# Processing Record 38 of Set 3 | talavera de la reina
# Processing Record 39 of Set 3 | oelde
# Processing Record 40 of Set 3 | ozgon
# City not found. Skipping...
# Processing Record 41 of Set 3 | paka
# Processing Record 42 of Set 3 | half moon bay
# Processing Record 43 of Set 3 | bollnas
# Processing Record 44 of Set 3 | bud
# Processing Record 45 of Set 3 | varzea da palma
# Processing Record 46 of Set 3 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 47 of Set 3 | hermanus
# Processing Record 48 of Set 3 | clyde river
# Processing Record 49 of Set 3 | rocha
# Processing Record 50 of Set 3 | riyadh
# Processing Record 1 of Set 4 | cabo san lucas
# Processing Record 2 of Set 4 | kavieng
# Processing Record 3 of Set 4 | mount isa
# Processing Record 4 of Set 4 | yarkovo
# Processing Record 5 of Set 4 | thinadhoo
# Processing Record 6 of Set 4 | udachnyy
# Processing Record 7 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 4 | pedasi
# Processing Record 9 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 4 | gualaquiza
# Processing Record 11 of Set 4 | cayenne
# Processing Record 12 of Set 4 | saint-philippe
# Processing Record 13 of Set 4 | isabela
# Processing Record 14 of Set 4 | ruwi
# Processing Record 15 of Set 4 | albany
# Processing Record 16 of Set 4 | saskylakh
# Processing Record 17 of Set 4 | tamiahua
# Processing Record 18 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 4 | muzhi
# Processing Record 20 of Set 4 | sur
# Processing Record 21 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 4 | palu
# Processing Record 23 of Set 4 | chuy
# Processing Record 24 of Set 4 | la libertad
# Processing Record 25 of Set 4 | hvolsvollur
# Processing Record 26 of Set 4 | muli
# Processing Record 27 of Set 4 | rawson
# Processing Record 28 of Set 4 | kaitangata
# Processing Record 29 of Set 4 | vestmannaeyjar
# Processing Record 30 of Set 4 | arawa
# Processing Record 31 of Set 4 | luba
# Processing Record 32 of Set 4 | henties bay
# Processing Record 33 of Set 4 | saint-francois
# Processing Record 34 of Set 4 | metro
# Processing Record 35 of Set 4 | waipawa
# Processing Record 36 of Set 4 | mar del plata
# Processing Record 37 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 4 | tazovskiy
# Processing Record 39 of Set 4 | mapiri
# Processing Record 40 of Set 4 | vallenar
# Processing Record 41 of Set 4 | pisco
# Processing Record 42 of Set 4 | otavi
# Processing Record 43 of Set 4 | saint-dizier
# Processing Record 44 of Set 4 | tuktoyaktuk
# Processing Record 45 of Set 4 | palmer
# Processing Record 46 of Set 4 | pangai
# Processing Record 47 of Set 4 | tarakan
# Processing Record 48 of Set 4 | sorland
# Processing Record 49 of Set 4 | ordu
# Processing Record 50 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 5 | dalbandin
# Processing Record 2 of Set 5 | victoria
# Processing Record 3 of Set 5 | dakar
# Processing Record 4 of Set 5 | richards bay
# Processing Record 5 of Set 5 | kununurra
# Processing Record 6 of Set 5 | vihti
# Processing Record 7 of Set 5 | georgetown
# Processing Record 8 of Set 5 | kapaa
# Processing Record 9 of Set 5 | elizabeth city
# Processing Record 10 of Set 5 | husavik
# Processing Record 11 of Set 5 | banepa
# Processing Record 12 of Set 5 | lagoa
# Processing Record 13 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 5 | alyangula
# Processing Record 15 of Set 5 | padang
# Processing Record 16 of Set 5 | kahului
# Processing Record 17 of Set 5 | iqaluit
# Processing Record 18 of Set 5 | raudeberg
# Processing Record 19 of Set 5 | bondoukou
# Processing Record 20 of Set 5 | sao joao da barra
# Processing Record 21 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 5 | lao cai
# Processing Record 23 of Set 5 | dikson
# Processing Record 24 of Set 5 | kyren
# Processing Record 25 of Set 5 | bilma
# Processing Record 26 of Set 5 | honningsvag
# Processing Record 27 of Set 5 | yeppoon
# Processing Record 28 of Set 5 | kerman
# Processing Record 29 of Set 5 | faanui
# Processing Record 30 of Set 5 | matagami
# Processing Record 31 of Set 5 | pevek
# Processing Record 32 of Set 5 | yazoo city
# Processing Record 33 of Set 5 | amahai
# Processing Record 34 of Set 5 | morant bay
# Processing Record 35 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 36 of Set 5 | mahajanga
# Processing Record 37 of Set 5 | inuvik
# Processing Record 38 of Set 5 | namibe
# Processing Record 39 of Set 5 | caluquembe
# Processing Record 40 of Set 5 | karratha
# Processing Record 41 of Set 5 | avarua
# Processing Record 42 of Set 5 | port moresby
# Processing Record 43 of Set 5 | palasa
# Processing Record 44 of Set 5 | keti bandar
# Processing Record 45 of Set 5 | nanga eboko
# Processing Record 46 of Set 5 | cabinda
# Processing Record 47 of Set 5 | hobyo
# Processing Record 48 of Set 5 | upernavik
# Processing Record 49 of Set 5 | la rioja
# Processing Record 50 of Set 5 | roma
# Processing Record 1 of Set 6 | maceio
# Processing Record 2 of Set 6 | egvekinot
# Processing Record 3 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 4 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 5 of Set 6 | saldanha
# Processing Record 6 of Set 6 | miles city
# Processing Record 7 of Set 6 | natal
# Processing Record 8 of Set 6 | maniitsoq
# Processing Record 9 of Set 6 | taltal
# Processing Record 10 of Set 6 | ikalamavony
# Processing Record 11 of Set 6 | ulagan
# Processing Record 12 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 13 of Set 6 | vila velha
# Processing Record 14 of Set 6 | kamina
# Processing Record 15 of Set 6 | port hedland
# Processing Record 16 of Set 6 | bethel
# Processing Record 17 of Set 6 | jeremie
# Processing Record 18 of Set 6 | delvada
# Processing Record 19 of Set 6 | rexburg
# Processing Record 20 of Set 6 | berlevag
# Processing Record 21 of Set 6 | kuala terengganu
# Processing Record 22 of Set 6 | poum
# Processing Record 23 of Set 6 | codajas
# Processing Record 24 of Set 6 | okahandja
# Processing Record 25 of Set 6 | port-gentil
# Processing Record 26 of Set 6 | segezha
# Processing Record 27 of Set 6 | pirojpur
# Processing Record 28 of Set 6 | talnakh
# Processing Record 29 of Set 6 | broken hill
# Processing Record 30 of Set 6 | la tuque
# Processing Record 31 of Set 6 | noumea
# Processing Record 32 of Set 6 | verkhniy ufaley
# Processing Record 33 of Set 6 | turukhansk
# Processing Record 34 of Set 6 | lavrentiya
# Processing Record 35 of Set 6 | ulladulla
# Processing Record 36 of Set 6 | bucerias
# Processing Record 37 of Set 6 | norrtalje
# Processing Record 38 of Set 6 | hualmay
# Processing Record 39 of Set 6 | saurimo
# Processing Record 40 of Set 6 | kencong
# Processing Record 41 of Set 6 | coihueco
# Processing Record 42 of Set 6 | ginda
# Processing Record 43 of Set 6 | palpa
# Processing Record 44 of Set 6 | solnechnyy
# Processing Record 45 of Set 6 | darab
# Processing Record 46 of Set 6 | presidente medici
# Processing Record 47 of Set 6 | humberto de campos
# Processing Record 48 of Set 6 | nanortalik
# Processing Record 49 of Set 6 | tara
# Processing Record 50 of Set 6 | catuday
# Processing Record 1 of Set 7 | lompoc
# Processing Record 2 of Set 7 | muros
# Processing Record 3 of Set 7 | cherskiy
# Processing Record 4 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 5 of Set 7 | bandarbeyla
# Processing Record 6 of Set 7 | sretensk
# Processing Record 7 of Set 7 | acarau
# Processing Record 8 of Set 7 | ongwediva
# Processing Record 9 of Set 7 | pokrovsk
# Processing Record 10 of Set 7 | ancud
# Processing Record 11 of Set 7 | khuzhir
# Processing Record 12 of Set 7 | great yarmouth
# Processing Record 13 of Set 7 | santa maria
# Processing Record 14 of Set 7 | taoudenni
# Processing Record 15 of Set 7 | marfino
# Processing Record 16 of Set 7 | leningradskiy
# Processing Record 17 of Set 7 | worpswede
# Processing Record 18 of Set 7 | mayskiy
# Processing Record 19 of Set 7 | shahr-e babak
# Processing Record 20 of Set 7 | arroyo
# Processing Record 21 of Set 7 | susanville
# Processing Record 22 of Set 7 | chiredzi
# Processing Record 23 of Set 7 | portobelo
# Processing Record 24 of Set 7 | zhangjiakou
# Processing Record 25 of Set 7 | hasaki
# Processing Record 26 of Set 7 | caraquet
# Processing Record 27 of Set 7 | krasnoshchekovo
# Processing Record 28 of Set 7 | meulaboh
# Processing Record 29 of Set 7 | athabasca
# Processing Record 30 of Set 7 | lasa
# Processing Record 31 of Set 7 | mount gambier
# Processing Record 32 of Set 7 | mildura
# Processing Record 33 of Set 7 | ponta do sol
# Processing Record 34 of Set 7 | luderitz
# Processing Record 35 of Set 7 | ko samui
# Processing Record 36 of Set 7 | portland
# Processing Record 37 of Set 7 | cheremukhovo
# Processing Record 38 of Set 7 | san quintin
# Processing Record 39 of Set 7 | balabac
# Processing Record 40 of Set 7 | gazanjyk
# Processing Record 41 of Set 7 | skali
# City not found. Skipping...
# Processing Record 42 of Set 7 | primorsko-akhtarsk
# Processing Record 43 of Set 7 | manokwari
# Processing Record 44 of Set 7 | silver city
# Processing Record 45 of Set 7 | celestun
# Processing Record 46 of Set 7 | gat
# Processing Record 47 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 48 of Set 7 | mercedes
# Processing Record 49 of Set 7 | kudahuvadhoo
# Processing Record 50 of Set 7 | elat
# Processing Record 1 of Set 8 | kiama
# Processing Record 2 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 4 of Set 8 | gushikawa
# Processing Record 5 of Set 8 | gravdal
# Processing Record 6 of Set 8 | lovozero
# Processing Record 7 of Set 8 | nishihara
# Processing Record 8 of Set 8 | sinegorye
# Processing Record 9 of Set 8 | kon tum
# Processing Record 10 of Set 8 | sisimiut
# Processing Record 11 of Set 8 | lakatoro
# Processing Record 12 of Set 8 | muroto
# Processing Record 13 of Set 8 | kalininsk
# Processing Record 14 of Set 8 | port augusta
# Processing Record 15 of Set 8 | okha
# Processing Record 16 of Set 8 | havelock
# Processing Record 17 of Set 8 | pietersburg
# Processing Record 18 of Set 8 | honiara
# Processing Record 19 of Set 8 | chapais
# Processing Record 20 of Set 8 | saint george
# Processing Record 21 of Set 8 | raybag
# Processing Record 22 of Set 8 | coffs harbour
# Processing Record 23 of Set 8 | souillac
# Processing Record 24 of Set 8 | san cristobal
# Processing Record 25 of Set 8 | caraballeda
# Processing Record 26 of Set 8 | santa rosa
# Processing Record 27 of Set 8 | zhigansk
# Processing Record 28 of Set 8 | erenhot
# Processing Record 29 of Set 8 | kruisfontein
# Processing Record 30 of Set 8 | nome
# Processing Record 31 of Set 8 | lucapa
# Processing Record 32 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 8 | mahon
# Processing Record 34 of Set 8 | chino valley
# Processing Record 35 of Set 8 | sitka
# Processing Record 36 of Set 8 | faya
# Processing Record 37 of Set 8 | tessalit
# Processing Record 38 of Set 8 | kempsey
# Processing Record 39 of Set 8 | kaliua
# Processing Record 40 of Set 8 | kirakira
# Processing Record 41 of Set 8 | evansville
# Processing Record 42 of Set 8 | shkoder
# Processing Record 43 of Set 8 | rivadavia
# Processing Record 44 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 8 | methoni
# Processing Record 46 of Set 8 | hrodna
# Processing Record 47 of Set 8 | buala
# Processing Record 48 of Set 8 | touros
# Processing Record 49 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 50 of Set 8 | goderich
# Processing Record 1 of Set 9 | port arthur
# Processing Record 2 of Set 9 | ternate
# Processing Record 3 of Set 9 | codrington
# Processing Record 4 of Set 9 | champerico
# Processing Record 5 of Set 9 | sokoni
# Processing Record 6 of Set 9 | ambilobe
# Processing Record 7 of Set 9 | shieli
# Processing Record 8 of Set 9 | ca mau
# Processing Record 9 of Set 9 | rieti
# Processing Record 10 of Set 9 | te anau
# Processing Record 11 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 9 | andenes
# Processing Record 13 of Set 9 | severo-kurilsk
# Processing Record 14 of Set 9 | khonsa
# Processing Record 15 of Set 9 | yulara
# Processing Record 16 of Set 9 | cabatuan
# Processing Record 17 of Set 9 | manaskent
# Processing Record 18 of Set 9 | zharkent
# Processing Record 19 of Set 9 | svetlyy
# Processing Record 20 of Set 9 | ouegoa
# Processing Record 21 of Set 9 | amapa
# Processing Record 22 of Set 9 | avera
# Processing Record 23 of Set 9 | broome
# Processing Record 24 of Set 9 | skjervoy
# Processing Record 25 of Set 9 | argelia
# Processing Record 26 of Set 9 | sao filipe
# Processing Record 27 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 28 of Set 9 | srednekolymsk
# Processing Record 29 of Set 9 | domoni
# Processing Record 30 of Set 9 | shingu
# Processing Record 31 of Set 9 | pochutla
# Processing Record 32 of Set 9 | vardo
# Processing Record 33 of Set 9 | robertson
# Processing Record 34 of Set 9 | burica
# City not found. Skipping...
# Processing Record 35 of Set 9 | chippewa falls
# Processing Record 36 of Set 9 | uribia
# Processing Record 37 of Set 9 | eyl
# Processing Record 38 of Set 9 | tautira
# Processing Record 39 of Set 9 | praia
# Processing Record 40 of Set 9 | sao gabriel da cachoeira
# Processing Record 41 of Set 9 | teya
# Processing Record 42 of Set 9 | sao miguel do araguaia
# Processing Record 43 of Set 9 | aitape
# Processing Record 44 of Set 9 | katsuyama
# Processing Record 45 of Set 9 | samarai
# Processing Record 46 of Set 9 | port said
# Processing Record 47 of Set 9 | mizpe ramon
# City not found. Skipping...
# Processing Record 48 of Set 9 | media luna
# Processing Record 49 of Set 9 | bae
# Processing Record 50 of Set 9 | washougal
# Processing Record 1 of Set 10 | bengkulu
# Processing Record 2 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 10 | severo-yeniseyskiy
# Processing Record 4 of Set 10 | ziro
# Processing Record 5 of Set 10 | daokou
# Processing Record 6 of Set 10 | deputatskiy
# Processing Record 7 of Set 10 | kenai
# Processing Record 8 of Set 10 | bethanien
# Processing Record 9 of Set 10 | namatanai
# Processing Record 10 of Set 10 | oroville
# Processing Record 11 of Set 10 | hofn
# Processing Record 12 of Set 10 | tabuk
# Processing Record 13 of Set 10 | fukue
# Processing Record 14 of Set 10 | camocim
# Processing Record 15 of Set 10 | atar
# Processing Record 16 of Set 10 | hattiesburg
# Processing Record 17 of Set 10 | kulhudhuffushi
# Processing Record 18 of Set 10 | san ramon
# Processing Record 19 of Set 10 | liozon
# Processing Record 20 of Set 10 | boa vista
# Processing Record 21 of Set 10 | altay
# Processing Record 22 of Set 10 | ixtapa
# Processing Record 23 of Set 10 | arlit
# Processing Record 24 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 10 | urubamba
# Processing Record 26 of Set 10 | darhan
# Processing Record 27 of Set 10 | matara
# Processing Record 28 of Set 10 | ahipara
# Processing Record 29 of Set 10 | aykhal
# Processing Record 30 of Set 10 | mouzakion
# City not found. Skipping...
# Processing Record 31 of Set 10 | atambua
# Processing Record 32 of Set 10 | bambanglipuro
# Processing Record 33 of Set 10 | vostok
# Processing Record 34 of Set 10 | tual
# Processing Record 35 of Set 10 | sao bernardo
# Processing Record 36 of Set 10 | akdepe
# Processing Record 37 of Set 10 | rio pardo
# Processing Record 38 of Set 10 | serramanna
# Processing Record 39 of Set 10 | togur
# Processing Record 40 of Set 10 | laem sing
# Processing Record 41 of Set 10 | anadyr
# Processing Record 42 of Set 10 | benguela
# Processing Record 43 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 10 | zaranj
# Processing Record 45 of Set 10 | zhanaozen
# Processing Record 46 of Set 10 | bandundu
# Processing Record 47 of Set 10 | chimore
# Processing Record 48 of Set 10 | isla vista
# Processing Record 49 of Set 10 | recke
# Processing Record 50 of Set 10 | turbat
# Processing Record 1 of Set 11 | lucea
# Processing Record 2 of Set 11 | moree
# Processing Record 3 of Set 11 | abu zabad
# Processing Record 4 of Set 11 | camana
# Processing Record 5 of Set 11 | skibbereen
# Processing Record 6 of Set 11 | samarina
# Processing Record 7 of Set 11 | lata
# Processing Record 8 of Set 11 | pandan
# Processing Record 9 of Set 11 | katsuura
# Processing Record 10 of Set 11 | taiyuan
# Processing Record 11 of Set 11 | krasnyye chetai
# Processing Record 12 of Set 11 | whitianga
# Processing Record 13 of Set 11 | iquique
# Processing Record 14 of Set 11 | selma
# Processing Record 15 of Set 11 | ibra
# Processing Record 16 of Set 11 | fortuna
# Processing Record 17 of Set 11 | macusani
# Processing Record 18 of Set 11 | san policarpo
# Processing Record 19 of Set 11 | haines junction
# Processing Record 20 of Set 11 | belaya gora
# Processing Record 21 of Set 11 | aquiraz
# Processing Record 22 of Set 11 | rio grande
# Processing Record 23 of Set 11 | tura
# Processing Record 24 of Set 11 | puerto del rosario
# Processing Record 25 of Set 11 | lewistown
# Processing Record 26 of Set 11 | dunedin
# Processing Record 27 of Set 11 | kalayaan
# Processing Record 28 of Set 11 | grand island
# Processing Record 29 of Set 11 | turayf
# Processing Record 30 of Set 11 | sakakah
# Processing Record 31 of Set 11 | pita
# Processing Record 32 of Set 11 | manaus
# Processing Record 33 of Set 11 | mugumu
# Processing Record 34 of Set 11 | kloulklubed
# Processing Record 35 of Set 11 | paamiut
# Processing Record 36 of Set 11 | pipri
# Processing Record 37 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 38 of Set 11 | pacific grove
# Processing Record 39 of Set 11 | tommot
# Processing Record 40 of Set 11 | katherine
# Processing Record 41 of Set 11 | abu dhabi
# Processing Record 42 of Set 11 | wilhelmshaven
# Processing Record 43 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 44 of Set 11 | khani
# Processing Record 45 of Set 11 | khandyga
# Processing Record 46 of Set 11 | chopda
# Processing Record 47 of Set 11 | alice springs
# Processing Record 48 of Set 11 | tezu
# Processing Record 49 of Set 11 | aswan
# Processing Record 50 of Set 11 | willowmore
# Processing Record 1 of Set 12 | vredendal
# Processing Record 2 of Set 12 | alibag
# Processing Record 3 of Set 12 | tawnat
# City not found. Skipping...
# Processing Record 4 of Set 12 | los llanos de aridane
# Processing Record 5 of Set 12 | cururupu
# Processing Record 6 of Set 12 | harboore
# Processing Record 7 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 12 | razdolinsk
# Processing Record 9 of Set 12 | mahibadhoo
# Processing Record 10 of Set 12 | hamilton
# Processing Record 11 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 12 of Set 12 | san patricio
# Processing Record 13 of Set 12 | diffa
# Processing Record 14 of Set 12 | buin
# Processing Record 15 of Set 12 | auki
# Processing Record 16 of Set 12 | sosnogorsk
# Processing Record 17 of Set 12 | riviere-au-renard
# Processing Record 18 of Set 12 | kadyy
# Processing Record 19 of Set 12 | nalut
# Processing Record 20 of Set 12 | ville-marie
# Processing Record 21 of Set 12 | torbay
# Processing Record 22 of Set 12 | kefar shemaryahu
# Processing Record 23 of Set 12 | coron
# Processing Record 24 of Set 12 | sovetsk
# Processing Record 25 of Set 12 | trinidad
# Processing Record 26 of Set 12 | flin flon
# Processing Record 27 of Set 12 | tuy hoa
# Processing Record 28 of Set 12 | ilhabela
# Processing Record 29 of Set 12 | pouebo
# Processing Record 30 of Set 12 | kang
# Processing Record 31 of Set 12 | syamzha
# Processing Record 32 of Set 12 | seminole
# Processing Record 33 of Set 12 | wuxue
# Processing Record 34 of Set 12 | grand-santi
# Processing Record 35 of Set 12 | ayagoz
# Processing Record 36 of Set 12 | rio bananal
# Processing Record 37 of Set 12 | zhob
# Processing Record 38 of Set 12 | soloneshnoye
# Processing Record 39 of Set 12 | sumbe
# Processing Record 40 of Set 12 | nemuro
# Processing Record 41 of Set 12 | nuevitas
# Processing Record 42 of Set 12 | bridlington
# Processing Record 43 of Set 12 | northam
# Processing Record 44 of Set 12 | olafsvik
# Processing Record 45 of Set 12 | hirara
# Processing Record 46 of Set 12 | asosa
# Processing Record 47 of Set 12 | anamur
# Processing Record 48 of Set 12 | davila
# Processing Record 49 of Set 12 | dingle
# Processing Record 50 of Set 12 | tiarei
# Processing Record 1 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 2 of Set 13 | margate
# Processing Record 3 of Set 13 | yerbogachen
# Processing Record 4 of Set 13 | clarksdale
# Processing Record 5 of Set 13 | phan thiet
# Processing Record 6 of Set 13 | fernley
# Processing Record 7 of Set 13 | dawei
# Processing Record 8 of Set 13 | chifeng
# Processing Record 9 of Set 13 | puro
# Processing Record 10 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 11 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 12 of Set 13 | saint-pierre
# Processing Record 13 of Set 13 | jamsa
# Processing Record 14 of Set 13 | aktas
# Processing Record 15 of Set 13 | ngunguru
# Processing Record 16 of Set 13 | madaoua
# Processing Record 17 of Set 13 | torit
# Processing Record 18 of Set 13 | palimbang
# Processing Record 19 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 13 | puerto narino
# Processing Record 21 of Set 13 | changji
# Processing Record 22 of Set 13 | am timan
# Processing Record 23 of Set 13 | hovd
# Processing Record 24 of Set 13 | iwanai
# Processing Record 25 of Set 13 | aden
# Processing Record 26 of Set 13 | fairbanks
# Processing Record 27 of Set 13 | sabang
# Processing Record 28 of Set 13 | gorin
# Processing Record 29 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 30 of Set 13 | puerto colombia
# Processing Record 31 of Set 13 | baiquan
# Processing Record 32 of Set 13 | malpe
# Processing Record 33 of Set 13 | smithers
# Processing Record 34 of Set 13 | vilhena
# Processing Record 35 of Set 13 | suifenhe
# Processing Record 36 of Set 13 | bonthe
# Processing Record 37 of Set 13 | tarhunah
# City not found. Skipping...
# Processing Record 38 of Set 13 | yar-sale
# Processing Record 39 of Set 13 | saint-augustin
# Processing Record 40 of Set 13 | leh
# Processing Record 41 of Set 13 | nantucket
# Processing Record 42 of Set 13 | vitim
# Processing Record 43 of Set 13 | poienile de sub munte
# Processing Record 44 of Set 13 | lumberton
# Processing Record 45 of Set 13 | inhambane
# Processing Record 46 of Set 13 | yinchuan
# Processing Record 47 of Set 13 | juybar
# Processing Record 48 of Set 13 | batagay-alyta
# Processing Record 49 of Set 13 | zhigalovo
# Processing Record 50 of Set 13 | shipunovo
# Processing Record 1 of Set 14 | fairlie
# Processing Record 2 of Set 14 | damaturu
# Processing Record 3 of Set 14 | ginir
# Processing Record 4 of Set 14 | george
# Processing Record 5 of Set 14 | palana
# Processing Record 6 of Set 14 | college
# Processing Record 7 of Set 14 | biak
# Processing Record 8 of Set 14 | bintulu
# Processing Record 9 of Set 14 | synya
# Processing Record 10 of Set 14 | san francisco
# Processing Record 11 of Set 14 | aanekoski
# Processing Record 12 of Set 14 | megion
# Processing Record 13 of Set 14 | mayumba
# Processing Record 14 of Set 14 | qaqortoq
# Processing Record 15 of Set 14 | hami
# Processing Record 16 of Set 14 | nayoro
# Processing Record 17 of Set 14 | dillon
# Processing Record 18 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 14 | neuquen
# Processing Record 20 of Set 14 | ayr
# Processing Record 21 of Set 14 | dandong
# Processing Record 22 of Set 14 | douglas
# Processing Record 23 of Set 14 | beringovskiy
# Processing Record 24 of Set 14 | grand gaube
# Processing Record 25 of Set 14 | nizhniy kuranakh
# Processing Record 26 of Set 14 | kungurtug
# Processing Record 27 of Set 14 | cairns
# Processing Record 28 of Set 14 | tromso
# Processing Record 29 of Set 14 | puerto madryn
# Processing Record 30 of Set 14 | general higinio morinigo
# Processing Record 31 of Set 14 | jawhar
# Processing Record 32 of Set 14 | ishurdi
# Processing Record 33 of Set 14 | chara
# Processing Record 34 of Set 14 | gamba
# Processing Record 35 of Set 14 | bertoua
# Processing Record 36 of Set 14 | prieska
# Processing Record 37 of Set 14 | solsvik
# City not found. Skipping...
# Processing Record 38 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 14 | walvis bay
# Processing Record 40 of Set 14 | carauari
# Processing Record 41 of Set 14 | madang
# Processing Record 42 of Set 14 | ust-tsilma
# Processing Record 43 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 14 | gorele
# Processing Record 45 of Set 14 | tapes
# Processing Record 46 of Set 14 | jiaonan
# Processing Record 47 of Set 14 | sinnamary
# Processing Record 48 of Set 14 | padilla
# Processing Record 49 of Set 14 | dasoguz
# Processing Record 50 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 1 of Set 15 | chester
# Processing Record 2 of Set 15 | monrovia
# Processing Record 3 of Set 15 | jinchang
# Processing Record 4 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 5 of Set 15 | iki-burul
# Processing Record 6 of Set 15 | lar gerd
# City not found. Skipping...
# Processing Record 7 of Set 15 | kano
# Processing Record 8 of Set 15 | salalah
# Processing Record 9 of Set 15 | kargapolye
# City not found. Skipping...
# Processing Record 10 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 15 | manicore
# Processing Record 12 of Set 15 | buraydah
# Processing Record 13 of Set 15 | asnaes
# Processing Record 14 of Set 15 | dubbo
# Processing Record 15 of Set 15 | san juan
# Processing Record 16 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 17 of Set 15 | marawi
# Processing Record 18 of Set 15 | along
# Processing Record 19 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 20 of Set 15 | beloha
# Processing Record 21 of Set 15 | horadiz
# Processing Record 22 of Set 15 | sarab
# Processing Record 23 of Set 15 | qianan
# Processing Record 24 of Set 15 | vila franca do campo
# Processing Record 25 of Set 15 | mastic beach
# Processing Record 26 of Set 15 | laurel
# Processing Record 27 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 15 | valparaiso
# Processing Record 29 of Set 15 | xinyang
# Processing Record 30 of Set 15 | streletskoye
# Processing Record 31 of Set 15 | bubaque
# Processing Record 32 of Set 15 | kaeo
# Processing Record 33 of Set 15 | piacabucu
# Processing Record 34 of Set 15 | afgoye
# City not found. Skipping...
# Processing Record 35 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 36 of Set 15 | christchurch
# Processing Record 37 of Set 15 | bukachacha
# Processing Record 38 of Set 15 | bartica
# Processing Record 39 of Set 15 | fort-shevchenko
# Processing Record 40 of Set 15 | saraj
# Processing Record 41 of Set 15 | ostersund
# Processing Record 42 of Set 15 | mersing
# Processing Record 43 of Set 15 | mongoumba
# Processing Record 44 of Set 15 | pokhara
# Processing Record 45 of Set 15 | minbu
# Processing Record 46 of Set 15 | khon kaen
# Processing Record 47 of Set 15 | inta
# Processing Record 48 of Set 15 | gunnedah
# Processing Record 49 of Set 15 | prince rupert
# Processing Record 50 of Set 15 | anakapalle
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Jurm  36.8648   70.8342     48.96        72          99
# 1  Narasannapeta  18.4167   84.0500     78.57        90           6
# 2       Klaksvik  62.2266   -6.5890     43.72        86         100
# 3   Constitucion -35.3333  -72.4167     61.65        84          56
# 4      Tuatapere -46.1333  167.6833     51.98        85          36
# 5      Bom Jesus  -9.0744  -44.3586     85.41        45          80
# 6         Barrow  71.2906 -156.7887     -7.58        84           0
# 7    Pangnirtung  66.1451  -65.7125     22.01        96          91
# 8    Yellowknife  62.4560 -114.3525      3.72        46          20
# 9        Siderno  38.2779   16.3020     46.33        74           9
#
#    Wind Speed Country       Description                 Date
# 0        1.23      AF   overcast clouds  2022-04-02 20:35:26
# 1        9.22      IN         clear sky  2022-04-02 20:35:27
# 2       19.57      FO   overcast clouds  2022-04-02 20:35:27
# 3       14.43      CL     broken clouds  2022-04-02 20:33:16
# 4        2.46      NZ  scattered clouds  2022-04-02 20:35:27
# 5        3.60      BR     broken clouds  2022-04-02 20:35:28
# 6       10.36      US              haze  2022-04-02 20:35:02
# 7        2.91      CA   overcast clouds  2022-04-02 20:35:28
# 8        2.30      CA        few clouds  2022-04-02 20:35:28
# 9       11.16      IT         clear sky  2022-04-02 20:35:29

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", 
                    "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0             Jurm      AF  2022-04-02 20:35:26  36.8648   70.8342     48.96
# 1    Narasannapeta      IN  2022-04-02 20:35:27  18.4167   84.0500     78.57
# 2         Klaksvik      FO  2022-04-02 20:35:27  62.2266   -6.5890     43.72
# 3     Constitucion      CL  2022-04-02 20:33:16 -35.3333  -72.4167     61.65
# 4        Tuatapere      NZ  2022-04-02 20:35:27 -46.1333  167.6833     51.98
# ..             ...     ...                  ...      ...       ...       ...
# 678      Khon Kaen      TH  2022-04-02 20:52:43  16.5000  102.0833     64.13
# 679           Inta      RU  2022-04-02 20:52:43  66.0317   60.1659      7.90
# 680       Gunnedah      AU  2022-04-02 20:52:43 -30.9833  150.2500     57.45
# 681  Prince Rupert      CA  2022-04-02 20:52:44  54.3161 -130.3201     42.89
# 682     Anakapalle      IN  2022-04-02 20:52:44  17.6833   83.0167     82.35
#
#      Humidity  Cloudiness  Wind Speed       Description
# 0          72          99        1.23   overcast clouds
# 1          90           6        9.22         clear sky
# 2          86         100       19.57   overcast clouds
# 3          84          56       14.43     broken clouds
# 4          85          36        2.46  scattered clouds
# ..        ...         ...         ...               ...
# 678        81          95        3.27   overcast clouds
# 679        94          90        7.16   overcast clouds
# 680        61          14        1.63        few clouds
# 681        75         100       40.29        light rain
# 682        82          40        6.91  scattered clouds
#
# [683 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
