# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("Weather_Database/WeatherPy_database.csv")
city_data_df
# Out:
#      City_ID           City Country                 Date      Lat       Lng  \
# 0          0           Jurm      AF  2022-04-02 20:35:26  36.8648   70.8342
# 1          1  Narasannapeta      IN  2022-04-02 20:35:27  18.4167   84.0500
# 2          2       Klaksvik      FO  2022-04-02 20:35:27  62.2266   -6.5890
# 3          3   Constitucion      CL  2022-04-02 20:33:16 -35.3333  -72.4167
# 4          4      Tuatapere      NZ  2022-04-02 20:35:27 -46.1333  167.6833
# ..       ...            ...     ...                  ...      ...       ...
# 678      678      Khon Kaen      TH  2022-04-02 20:52:43  16.5000  102.0833
# 679      679           Inta      RU  2022-04-02 20:52:43  66.0317   60.1659
# 680      680       Gunnedah      AU  2022-04-02 20:52:43 -30.9833  150.2500
# 681      681  Prince Rupert      CA  2022-04-02 20:52:44  54.3161 -130.3201
# 682      682     Anakapalle      IN  2022-04-02 20:52:44  17.6833   83.0167
#
# ...

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 

min_temp = float(input("What is the minimum temperature (°F) you would like for your trip? "))
max_temp = float(input("What is the maximum temperature (°F) you would like for your trip? "))
# Out:
# What is the minimum temperature (°F) you would like for your trip? 75
# What is the maximum temperature (°F) you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.

preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df
# Out:
#      City_ID           City Country                 Date      Lat      Lng  \
# 1          1  Narasannapeta      IN  2022-04-02 20:35:27  18.4167  84.0500
# 5          5      Bom Jesus      BR  2022-04-02 20:35:28  -9.0744 -44.3586
# 10        10            Gao      ML  2022-04-02 20:33:33  16.6362   1.6370
# 13        13      Hithadhoo      MV  2022-04-02 20:35:29  -0.6000  73.0833
# 16        16          Dhone      IN  2022-04-02 20:35:30  15.4167  77.8833
# ..       ...            ...     ...                  ...      ...      ...
# 667      667      Piacabucu      BR  2022-04-02 20:52:39 -10.4056 -36.4344
# 670      670        Bartica      GY  2022-04-02 20:52:40   6.4000 -58.6167
# 675      675      Mongoumba      CF  2022-04-02 20:52:42   3.6415  18.5936
# 677      677          Minbu      MM  2022-04-02 20:52:42  20.1833  94.8833
# 682      682     Anakapalle      IN  2022-04-02 20:52:44  17.6833  83.0167
#
# ...

# %%
# 4a. Determine if there are any empty rows.
# there are no null values if sum equals 0
sum(preferred_cities_df.isnull().sum())
# Out:
# 0

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.dropna()

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#               City Country  Max Temp           Description      Lat      Lng  \
# 1    Narasannapeta      IN     78.57             clear sky  18.4167  84.0500
# 5        Bom Jesus      BR     85.41         broken clouds  -9.0744 -44.3586
# 10             Gao      ML     87.21             clear sky  16.6362   1.6370
# 13       Hithadhoo      MV     82.85            few clouds  -0.6000  73.0833
# 16           Dhone      IN     81.59             clear sky  15.4167  77.8833
# ..             ...     ...       ...                   ...      ...      ...
# 667      Piacabucu      BR     78.31            few clouds -10.4056 -36.4344
# 670        Bartica      GY     75.52  heavy intensity rain   6.4000 -58.6167
# 675      Mongoumba      CF     79.39       overcast clouds   3.6415  18.5936
# 677          Minbu      MM     82.74            few clouds  20.1833  94.8833
# 682     Anakapalle      IN     82.35      scattered clouds  17.6833  83.0167
#
#     Hotel Name
# 1
# 5
# 10
# 13
# 16
# ...

# %%
# Test looping through first 3 rows:
# hotel_df = hotel_df[:3]
# hotel_df

# %%
# 6a. Set parameters to search for hotels within 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# Initialize counters for hotels found and skipped
found = 0
skipped = 0

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():

    # 6c. Get latitude and longitude from DataFrame
    lat = row['Lat']
    lng = row['Lng']
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
        hotel = hotels["results"][0]["name"]
        print(f"Hotel found: {hotel}")
        found += 1
    except (IndexError):
        # Skipped cities get assigned "" and isn't recognized as null value. Instead, set to None so row can be dropped using dropna()
        hotel_df.loc[index, "Hotel Name"]= None
        print("Hotel not found... skipping.")
        skipped += 1

print(f"Done finding hotels. {found} hotels found, {skipped} skipped")
# Out:
# Hotel found: AVK events and catering
# Hotel found: Hotel Brasão & Floricultura Bella Flor
# Hotel not found... skipping.
# Hotel found: Scoop Guest House
# Hotel found: Pennera Rakesh
# Hotel found: Hotel Manglares
# Hotel found: Shandrani Beachcomber Resort & Spa
# Hotel found: ZINGARA 76ft Catamaran, full crew-all included
# Hotel found: Finch Bay Galapagos Hotel
# Hotel found: Casa Tia Villa
# Hotel not found... skipping.
# Hotel found: Uruna Bay Retreat
# Hotel found: Castle Motor Lodge Motel
# Hotel found: Tanna Lodge
# Hotel found: Lorengau Harbourside Hotel
# Hotel found: Taloa Heights
# Hotel found: Pousada Porto Praia
# Hotel found: Isles Sunset Lodge
# Hotel found: "Plantation Bed and Breakfast
# Hotel found: Hotel Cerro De Zumba
# Hotel found: Atlantis Hotel
# Hotel found: Sea Lounge! Bar, Club & Restaurant
# Hotel found: Pousada dos Navegantes
# Hotel found: Orient Apartments
# Hotel found: Hilo Hawaiian Hotel
# Hotel found: Hospitality Carnarvon
# ...

# %%
hotel_df.count()
# Out:
# City           225
# Country        225
# Max Temp       225
# Description    225
# Lat            225
# Lng            225
# Hotel Name     209
# dtype: int64

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna()
clean_hotel_df.count()
# Out:
# City           209
# Country        209
# Max Temp       209
# Description    209
# Lat            209
# Lng            209
# Hotel Name     209
# dtype: int64

# %%
# 8a. Create the output File (CSV)
output_data_file = "Vacation_Search/WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
locations
# Out:
#          Lat      Lng
# 1    18.4167  84.0500
# 5    -9.0744 -44.3586
# 13   -0.6000  73.0833
# 16   15.4167  77.8833
# 19   16.5167 -98.7500
# ..       ...      ...
# 665  11.2833 -15.8333
# 667 -10.4056 -36.4344
# 670   6.4000 -58.6167
# 677  20.1833  94.8833
# 682  17.6833  83.0167
#
# [209 rows x 2 columns]

# %%
# 11a. Add a marker layer with pop-up info box for each city to the map. 

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.85)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 11b. Display the figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
